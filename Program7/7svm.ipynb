# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# %%
data=load_digits()
x=data.data
y=data.target

# %%
plt.gray()
for i in range (4):
    plt.matshow(data.images[i])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sl= StandardScaler()
x_train=sl.fit_transform(x_train)
x_test=sl.transform(x_test)

# %%
model=SVC()
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
model.score(x_test,y_test)
# Out:
# 0.11388888888888889

# %%
y_pred=model.predict(x_test)
from sklearn.metrics import confusion_matrix,classification_report
import seaborn as sb

print(classification_report(y_test,y_pred))

sb.heatmap(confusion_matrix(y_test,y_pred),annot=True,cmap='Blues')
# Out:
# C:\Users\vishn\anaconda3\envs\py310\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\vishn\anaconda3\envs\py310\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\vishn\anaconda3\envs\py310\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.00      0.00      0.00        41
#            2       0.00      0.00      0.00        39
#            3       0.00      0.00      0.00        41
#            4       0.11      1.00      0.20        41
#            5       0.00      0.00      0.00        25
#            6       0.00      0.00      0.00        33
#            7       0.00      0.00      0.00        37
#            8       0.00      0.00      0.00        32
#            9       0.00      0.00      0.00        41
#
#     accuracy                           0.11       360
#    macro avg       0.01      0.10      0.02       360
# weighted avg       0.01      0.11      0.02       360
# <Axes: >

# %%
print(y_test,"predicted=",y_pred)
# Out:
# [9 6 7 5 1 8 6 4 0 9 3 1 9 9 0 4 7 6 2 1 2 8 6 7 1 4 2 4 1 8 8 3 2 6 3 8 4
#  6 3 9 2 0 4 3 9 0 7 5 2 9 9 0 4 0 1 4 7 6 7 3 1 7 2 9 2 7 7 2 6 3 7 2 1 8
#  8 7 2 9 3 5 9 2 9 5 3 4 1 7 8 2 0 1 2 3 6 3 6 0 9 9 4 2 4 1 8 2 4 6 6 3 2
#  1 7 3 4 5 7 8 1 3 9 6 6 7 6 7 1 4 7 5 2 7 3 0 0 9 7 8 2 7 0 6 4 4 5 1 7 1
#  7 0 4 6 9 9 2 9 1 8 3 1 1 2 0 6 6 2 5 3 6 2 2 5 4 2 8 3 9 3 2 4 1 0 2 3 1
#  8 0 3 7 7 9 0 4 1 7 1 7 6 5 9 7 9 4 0 1 4 3 5 4 4 0 3 5 1 9 2 9 4 0 9 5 8
#  5 2 8 1 9 0 8 3 0 4 5 4 4 2 8 2 8 8 1 6 3 1 1 5 6 1 6 9 8 4 2 6 5 4 9 2 6
#  3 2 3 3 5 8 3 1 6 3 7 9 7 1 3 5 0 0 3 4 6 2 8 2 7 4 1 3 0 3 7 7 9 9 1 9 7
#  2 1 0 6 9 8 9 4 9 7 3 4 5 0 4 1 9 9 4 4 2 8 5 4 5 3 5 1 5 8 0 6 4 1 7 4 3
#  3 7 8 5 8 0 2 1 0 0 6 3 3 6 6 9 8 9 9 4 7 8 8 8 1 3 1] predicted= [4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4]
