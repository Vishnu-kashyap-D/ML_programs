# %%
from sklearn import tree
from sklearn.datasets import load_iris
import pandas as pd

# %%
d = load_iris()
df = pd.DataFrame(d.data,columns=d.feature_names)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df=df[["sepal width (cm)","petal width (cm)"]]
y=d.target

# %%
df.head()
# Out:
#    sepal width (cm)  petal width (cm)
# 0               3.5               0.2
# 1               3.0               0.2
# 2               3.2               0.2
# 3               3.1               0.2
# 4               3.6               0.2

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(df,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion = 'entropy' ,max_depth=4)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
y_pred = model.predict(x_test)
from sklearn.metrics import confusion_matrix
import seaborn as sb
sb.heatmap(confusion_matrix(y_test,y_pred),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
tree.plot_tree(model,feature_names=df.columns)
# Out:
# [Text(0.4, 0.9, 'petal width (cm) <= 0.75\nentropy = 1.584\nsamples = 120\nvalue = [39, 42, 39]'),
#  Text(0.3, 0.7, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.35, 0.8, 'True  '),
#  Text(0.5, 0.7, 'petal width (cm) <= 1.75\nentropy = 0.999\nsamples = 81\nvalue = [0, 42, 39]'),
#  Text(0.45, 0.8, '  False'),
#  Text(0.2, 0.5, 'petal width (cm) <= 1.35\nentropy = 0.433\nsamples = 45\nvalue = [0, 41, 4]'),
#  Text(0.1, 0.3, 'entropy = 0.0\nsamples = 23\nvalue = [0, 23, 0]'),
#  Text(0.3, 0.3, 'sepal width (cm) <= 2.85\nentropy = 0.684\nsamples = 22\nvalue = [0, 18, 4]'),
#  Text(0.2, 0.1, 'entropy = 0.985\nsamples = 7\nvalue = [0, 4, 3]'),
#  Text(0.4, 0.1, 'entropy = 0.353\nsamples = 15\nvalue = [0, 14, 1]'),
#  Text(0.8, 0.5, 'petal width (cm) <= 1.85\nentropy = 0.183\nsamples = 36\nvalue = [0, 1, 35]'),
#  Text(0.7, 0.3, 'sepal width (cm) <= 3.15\nentropy = 0.503\nsamples = 9\nvalue = [0, 1, 8]'),
#  Text(0.6, 0.1, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 7]'),
#  Text(0.8, 0.1, 'entropy = 1.0\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.9, 0.3, 'entropy = 0.0\nsamples = 27\nvalue = [0, 0, 27]')]
